# %% [markdown]
# # Operation on Iris dataset

# %% [markdown]
# ## 1. Read the dataset to python environment

# %% [markdown]
# Note: Both notebook and dataset are in same directory

# %%
import pandas as pd

# %%
iris=pd.read_excel("iris.xls")

# %%
iris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 2. Display the columns in the dataset

# %%
print("Column details are as below")
iris.columns
# Out:
# Column details are as below
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ## 3. Calculate the mean of each column of the dataset

# %%
iris[["SL","SW","PL","PW"]].mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ## 4. Check for the null values present in the dataset

# %%
iris[iris.isnull()]
# Out:
#      SL  SW  PL  PW Classification
# 0   NaN NaN NaN NaN            NaN
# 1   NaN NaN NaN NaN            NaN
# 2   NaN NaN NaN NaN            NaN
# 3   NaN NaN NaN NaN            NaN
# 4   NaN NaN NaN NaN            NaN
# ..   ..  ..  ..  ..            ...
# 145 NaN NaN NaN NaN            NaN
# 146 NaN NaN NaN NaN            NaN
# 147 NaN NaN NaN NaN            NaN
# 148 NaN NaN NaN NaN            NaN
# 149 NaN NaN NaN NaN            NaN
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
iris.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
iris.sample(10)
# Out:
#       SL   SW   PL   PW   Classification
# 6    4.6  3.4  1.4  0.3      Iris-setosa
# 41   4.5  2.3  1.3  0.3      Iris-setosa
# 133  6.3  2.8  5.1  1.5   Iris-virginica
# 112  6.8  3.0  5.5  2.1   Iris-virginica
# 11   4.8  3.4  1.6  0.2      Iris-setosa
# 93   5.0  2.3  3.3  1.0  Iris-versicolor
# 34   4.9  3.1  1.5  0.1      Iris-setosa
# 68   6.2  2.2  4.5  1.5  Iris-versicolor
# 87   6.3  2.3  4.4  1.3  Iris-versicolor
# 29   4.7  3.2  1.6  0.2      Iris-setosa

# %% [markdown]
# ### Visual 1

# %% [markdown]
# #### Histogram showing frequency of data recorded

# %%
iris.plot.hist(subplots=True, layout=(2,2), figsize=(10, 10), bins=20)
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %% [markdown]
# ### Visual 2

# %% [markdown]
# #### Kernel Density Plot of various species on the basis of sepal lenth

# %%
g = sns.FacetGrid(iris, col='Classification')
g = g.map(sns.kdeplot, 'SL')

# %% [markdown]
# ### Visual 2

# %% [markdown]
# #### Pair Plot

# %%
plt.close()
sns.set_style("whitegrid")
sns.pairplot(iris,hue="Classification",height=3, diag_kind="kde")
plt.show()
